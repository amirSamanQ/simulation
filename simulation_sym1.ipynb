# %%
import pandas as pd 
import time
import math
import random

# %%
# generating random numbers

def exponential(lambd):
    r = random.random()
    return -(1 / lambd) * math.log(r)


def uniform(a, b):
    r = random.random()
    return a + (b - a) * r

def Triangular(max,mean,min):
    r = random.random()
    F_c = (max - min) / (mean - min)
    if r <= F_c:
        return min + math.sqrt(r * (mean - min) * (max - min))
    else:
        return mean - math.sqrt((1 - r) * (mean - min) * (mean - max))

def Normal(m,v):
    u1 = random.random()
    u2 = random.random()
    z0 = math.sqrt(-2.0 * math.log(u1)) * math.cos(2 * math.pi * u2)
    norm = z0 * math.sqrt(v) + m

    return norm

def uniform_dis(a,b):
    r = random.random()

    value = math.floor(a + r* (b - a + 1))

    return value

# %% [markdown]
# ![{14F7EF80-33A8-46DB-823D-015E76303FE8}.png](attachment:{14F7EF80-33A8-46DB-823D-015E76303FE8}.png)

# %%
import pandas as pd 
import time
import math
import random

# generating random numbers

def exponential(lambd):
    r = random.random()
    return -(1 / lambd) * math.log(r)


def uniform(a, b):
    r = random.random()
    return a + (b - a) * r

def Triangular(max,mean,min):
    r = random.random()
    F_c = (max - min) / (mean - min)
    if r <= F_c:
        return min + math.sqrt(r * (mean - min) * (max - min))
    else:
        return mean - math.sqrt((1 - r) * (mean - min) * (mean - max))

def Normal(m,v):
    u1 = random.random()
    u2 = random.random()
    z0 = math.sqrt(-2.0 * math.log(u1)) * math.cos(2 * math.pi * u2)
    norm = z0 * math.sqrt(v) + m

    return norm

def uniform_dis(a,b):
    r = random.random()

    value = math.floor(a + r* (b - a + 1))

    return value

def update_cumulative_stats():
    initial_tresh = 10000
    if(T < initial_tresh or T - initial_tresh == 0):
        return
    # Update efficiency of beds
    stats['eff_u'] = ((last_T - initial_tresh)*stats['eff_u'] + (T - last_T)*state_vars['U'])/(T-initial_tresh)
    stats['eff_b'] = ((last_T - initial_tresh)*stats['eff_b'] + (T - last_T)*state_vars['B'])/(T-initial_tresh)
    stats['eff_l'] = ((last_T - initial_tresh)*stats['eff_l'] + (T - last_T)*state_vars['L'])/(T-initial_tresh)
    stats['eff_s'] = ((last_T - initial_tresh)*stats['eff_s'] + (T - last_T)*state_vars['S'])/(T-initial_tresh)
    stats['eff_g'] = ((last_T - initial_tresh)*stats['eff_g'] + (T - last_T)*state_vars['G'])/(T-initial_tresh)
    stats['eff_icu'] = ((last_T - initial_tresh)*stats['eff_icu'] + (T - last_T)*state_vars['IC'])/(T-initial_tresh)
    stats['eff_ccu'] = ((last_T - initial_tresh)*stats['eff_ccu'] + (T - last_T)*state_vars['CC'])/(T-initial_tresh)
    # Update queue statistics
    for i in Q_lists:
        Q_lists[i]['avg'] = ((last_T - initial_tresh)* Q_lists[i]['avg'] + (T - last_T)*len( Q_lists[i]['que']))/(T-initial_tresh)
        Q_lists[i]['max'] = max( Q_lists[i]['max'],len( Q_lists[i]['que']))


state_vars = {'U':10,'UQ':0,'B':35,'BQ':0,'L':5,'ELQ':0,'NLQ':0,'S':45,'ESQ':0,'NSQ':0,'RS':0,'G':45,'GQ':0,'IC':10,'NIC':0,'ICQ':0,'CC':5,'NCC':0,'CCQ':0}
type_of_events = ['ES','NS','LS','LE','SS','SE','RSE','GE','IC','NIC','CCE','NCCE','NS','NE']
Q_lists = { 'UQ': {'que': [], 'avg': 0, 'max': 0}, 'BQ': {'que': [], 'avg': 0, 'max': 0},
            'ELQ': {'que': [], 'avg': 0, 'max': 0}, 'NLQ': {'que': [], 'avg': 0, 'max': 0},
            'ESQ': {'que': [], 'avg': 0, 'max': 0}, 'NSQ': {'que': [], 'avg': 0, 'max': 0}, 
            'GQ': {'que': [], 'avg': 0, 'max': 0}, 'ICQ': {'que': [], 'avg': 0, 'max': 0}, 
            'CCQ': {'que': [], 'avg': 0, 'max': 0} }
patient_dict = {} # List of Patient objects that have entered the system
stats = {'fully_u':0,'eff_u':0,'eff_b':0,'eff_l':0,'eff_s':0,'eff_g':0,'eff_icu':0,'eff_ccu':0}
patient_pos = ['U','UQ','B','BQ','L','LQ','S','SQ','G','GQ','ICU','ICUQ','CCU','CCUQ']
T = 0 # Current event time
last_T = 0 # Last event time
number_of_patient = 0  # Total number of patients entered the system
FEL = [] # List of Event objects, sorted by time, 
class Patient():
    def __init__(self,arrival_time,type,number):
        # Initialize patient properties
        self.arrival = arrival_time
        self.type = type # 'E': Emergency , 'N': normal
        self.number = number # Patient number
        self.departure = 0
        self.sur_entrance_time = 0
        self.sur_counter = 0 # Surgery count
        self.s_arrival_time = -1 # Arrival time of current section
        self.surgery_type = None # 's' simple, 'm' medium, 'c' complex
        self.current_pos = None # Current position
        # Waiting times in queues
        self.sbq = 0
        self.sb = 0
        self.uqt = 0 # Waiting in emergency queue
        self.bqt = 0 # Waiting in bed queue
        self.lqt = 0 # Waiting in laboratory queue
        self.sqt = 0 # Waiting in surgery queue
        self.gqt = 0 # Waiting in ward(G) que
        self.icuqt = 0 # Waiting in ICU que
        self.ccuqt = 0 # Waitng in CCU que
        # Service times
        self.ut = 0 # Duration in emergency
        self.lt = 0 # Duration in laboratory
        self.st = 0 # Duration of surgery
        self.gt = 0 # Duration in ward(G)
        self.icut = 0 # Duration in ICU
        self.ccut = 0 # Duraiont in CCU

    def get_values(self): 
        return { 'arrival_time': self.arrival, 'sur_entrance_time': self.sur_entrance_time, 'sur_counter': self.sur_counter,
                 'departure': self.departure, 's_arrival_time': self.s_arrival_time, 'surgery_type': self.surgery_type,
                 'current_pos': self.current_pos, 'uqt': self.uqt, 'bqt': self.bqt, 'lqt': self.lqt, 'sqt': self.sqt, 'gqt': self.gqt,
                 'icuqt': self.icuqt, 'ccuqt': self.ccuqt, 'ut': self.ut, 'lt': self.lt, 'st': self.st, 'gt': self.gt, 'icut': self.icut,
                 'ccut': self.ccut ,'type':self.type}
class Event():
    """
    Represents an event in the simulation.
    type: An element of ['ES','NS','LS','LE','SS','SE','RSE','GE','IC','NIC','CCE','NCCE','NS','NE']
    patient: Patient number associated with the event
    time: The time when the event occurs
    """
    def __init__(self,type,patient,time,FEL):
        self.type = type
        self.patient = patient
        self.time = time
        self.update_FEL(FEL)
    def update_FEL(self,FEL):
        # Insert event into Future Event List (FEL) sorted by time
        for i in range(len(FEL)):
            if(self.time < FEL[i].time):
                FEL.insert(i,self)
                return       
        FEL.append(self)           
def ES():
    # Check if it is a single or group entrance
    global number_of_patient,T,last_T
    rn = random.random() # Placeholder value, should be edited , random.random()
    if(rn < 0.995):
        # Single entrance
        if(state_vars['UQ'] < 10): # Check the emergency queue length
            # patient_number = len(patient_dict) + 1
            number_of_patient += 1
            patient_dict[number_of_patient] = Patient(T, 'E', number_of_patient) # Add new emergency patient
            if(state_vars['U'] > 0): # Check if there is an available emergency bed
                print('####')
                state_vars['U'] -= 1 # Update count of available emergency beds
                print([(i.type,i.time) for i in FEL])
                Event('LS', number_of_patient, T + 10, FEL) # Schedule lab start event
                print([(i.type,i.time) for i in FEL])
                patient_dict[number_of_patient].current_pos = 'U' # Update current position of patient
                patient_dict[number_of_patient].s_arrival_time = T # Update arrival time of current position
            else: # No available emergency bed
                state_vars['UQ'] += 1 # Update length of emergency queue
                Q_lists['UQ']['que'].append(number_of_patient) # Add patient to emergency queue
                patient_dict[number_of_patient].current_pos = 'UQ' # Update current position of patient
                patient_dict[number_of_patient].s_arrival_time = T # Update arrival time of current position
        else: # Emergency queue capacity is full
            stats['fully_u'] += 1 # Update fully_u statistic
    else:
        # Group entrance
        number = uniform_dis(2,5) # Generate random number
        if(number <= state_vars['U']):
            for i in range(number):
                number_of_patient += 1
                delay_time = random.random()/100
                patient_dict[number_of_patient] = Patient(T+delay_time ,'E', number_of_patient) # Add new emergency patients
                Event('LS', number_of_patient, T + delay_time+ 10, FEL) # Schedule lab start event
                patient_dict[number_of_patient].current_pos = 'U' # Update current position of the patient
                patient_dict[number_of_patient].s_arrival_time = T+delay_time # Update arrival time of the current position
            state_vars['U'] -= number # Update count of available emergency beds 
    # Generate next arrival
    rn = random.random()
    if(rn<=.25):
        interarrival_time = exponential(1/4)*60
        Event('ES', number_of_patient + 1, T + interarrival_time, FEL)
    else:
        interarrival_time = exponential(1)*60
        Event('NS',number_of_patient + 1, T + interarrival_time, FEL )
def NS():
    global number_of_patient,T,last_T
    number_of_patient += 1
    patient_dict[number_of_patient] = Patient(T, 'N', number_of_patient) # Add new normal patient
    if(state_vars['B'] > 0): # Check if there is an available bed in B
        state_vars['B'] -= 1 # Update count of available beds
        Event('LS', number_of_patient, T + 60, FEL) # Schedule lab start event
        patient_dict[number_of_patient].current_pos = 'B' # Update current position of the patient
        patient_dict[number_of_patient].s_arrival_time = T # Update arrival time of the current position
        patient_dict[number_of_patient].sb = T
    else:
        state_vars['BQ'] += 1 # Update length of B queue
        Q_lists['BQ']['que'].append(number_of_patient) # Add patient to B queue
        patient_dict[number_of_patient].sbq = T
        patient_dict[number_of_patient].current_pos = 'BQ' # Update current position of the patient
        patient_dict[number_of_patient].s_arrival_time = T # Update arrival time of the current position
    
    rn = random.random()# determine next patient type
    if(rn<=.25):#emergency patient
        interarrival_time = exponential(1/4)*60
        Event('ES', number_of_patient + 1, T + interarrival_time, FEL)
    else:#normal patient
        interarrival_time = exponential(1)*60
        Event('NS',number_of_patient + 1, T + interarrival_time, FEL )

def LS(event):
    global number_of_patient,T,last_T
    patient_number = event.patient
    if(patient_dict[patient_number].type == 'E'): # Emergency patient!
        if(state_vars['L'] > 0): # Free lab available
            state_vars['L'] -= 1
            lab_duration = uniform(28,32) # Should be edited with actual duration
            Event('LE', patient_number, T + lab_duration, FEL)
            patient_dict[patient_number].current_pos = 'L'
            patient_dict[patient_number].s_arrival_time = T
        else: # Full lab, patient should wait in queue
            state_vars['ELQ'] += 1
            Q_lists['ELQ']['que'].append(patient_number)
            patient_dict[patient_number].current_pos = 'LQ'
            patient_dict[patient_number].s_arrival_time = T
    else: # Normal patient
        if(state_vars['L'] > 0): # Free lab available
            state_vars['L'] -= 1
            lab_duration = uniform(28,32) # Should be edited with actual duration
            Event('LE', patient_number, T + lab_duration, FEL)
            patient_dict[patient_number].current_pos = 'L'
            patient_dict[patient_number].s_arrival_time = T
        else: # Full lab, patient should wait in queue
            state_vars['NLQ'] += 1
            Q_lists['NLQ']['que'].append(patient_number)
            patient_dict[patient_number].current_pos = 'LQ'
            patient_dict[patient_number].s_arrival_time = T

def LE(event):
    global number_of_patient,T,last_T
    patient_number = event.patient
    # Handle forward events
    if(patient_dict[patient_number].type == 'E'): # Check if the patient is an emergency patient
        ss_arrival_time = Triangular(100,75,5) # Set surgery arrival time for emergency patient
        Event('SS',patient_number,T + ss_arrival_time,FEL)
        patient_dict[patient_number].current_pos = 'U' # Update current position to 'U'
        patient_dict[patient_number].lt = T - patient_dict[patient_number].s_arrival_time # Update the leave time
        patient_dict[patient_number].s_arrival_time = T # Update the arrival time
    elif(patient_dict[patient_number].type == 'N'):
        ss_arrival_time = 60*24 # Set surgery arrival time for normal patient
        Event('SS',patient_number,T + ss_arrival_time,FEL)
        patient_dict[patient_number].current_pos = 'B' # Update current position to 'B'
        patient_dict[patient_number].lt = T - patient_dict[patient_number].s_arrival_time # Update the leave time
        patient_dict[patient_number].s_arrival_time = T # Update the arrival time
    else:
        raise Exception('patient type is not E nor U!')
    # Handle backward events
    if(state_vars['ELQ'] > 0): # Check if there are emergency patients in the lab queue
        patient_number = Q_lists['ELQ']['que'].pop(0) # Get the first patient in the ELQ queue
        state_vars['ELQ'] -= 1 # Update the ELQ state variable
        lab_duration = uniform(28,32) # Set lab duration (should be edited)
        Event('LE',patient_number,T + lab_duration,FEL)
        patient_dict[patient_number].current_pos = 'L' # Update current position to 'L'
        patient_dict[patient_number].lqt = T - patient_dict[patient_number].s_arrival_time # Update the lab queue time
        patient_dict[patient_number].s_arrival_time = T # Update the arrival time
    elif(state_vars['NLQ']>0): # Check if there are normal patients in the lab queue
        patient_number = Q_lists['NLQ']['que'].pop(0) # Get the first patient in the NLQ queue
        state_vars['NLQ'] -= 1 # Update the NLQ state variable
        lab_duration = uniform(28,32) # Set lab duration (should be edited)
        Event('LE',patient_number,T + lab_duration,FEL)
        patient_dict[patient_number].current_pos = 'L' # Update current position to 'L'
        patient_dict[patient_number].lqt = T - patient_dict[patient_number].s_arrival_time # Update the lab queue time
        patient_dict[patient_number].s_arrival_time = T # Update the arrival time
    else:
        state_vars['L'] += 1

def SS(event):
    global number_of_patient,T,last_T
    patient_number = event.patient
    ra = random.random()  # Type of surgery
    if ra <= 0.5:
        sur_type = 's'
    elif 0.5 < ra <= 0.95:
        sur_type = 'm'
    else:
        sur_type = 'c' 
    patient_dict[patient_number].surgery_type = sur_type
    # Forward operations
    if state_vars['S'] > 0:
        state_vars['S'] -= 1
        if sur_type == 's':  # Simple surgery
            sur_duration = Normal(30.22 , 22.56)  # Duration of simple surgery
        elif sur_type == 'm':  # Medium surgery
            sur_duration = Normal(74.54 , 99.11)  # Duration of medium surgery
        else:  # Complex surgery
            sur_duration = Normal(242.03 , 4003.67) # Duration of complex surgery
        Event('SE', patient_number, T + sur_duration, FEL)
        patient_dict[patient_number].current_pos = 'S'
        patient_dict[patient_number].st += sur_duration
        patient_dict[patient_number].sur_counter += 1
        patient_dict[patient_number].sur_entrance_time = T
    else:  # No available surgery room
        if patient_dict[patient_number].type == 'E':  # Emergency patient
            state_vars['ESQ'] += 1
            Q_lists['ESQ']['que'].append(patient_number)
        else:  # Non-emergency patient
            state_vars['NSQ'] += 1
            Q_lists['NSQ']['que'].append(patient_number)
        patient_dict[patient_number].current_pos = 'QS'
        patient_dict[patient_number].s_arrival_time = T
    # Backward operations
    if patient_dict[patient_number].type == 'E':
        if state_vars['UQ'] > 0:
            state_vars['UQ'] -= 1
            patient_number = Q_lists['UQ']['que'].pop(0)
            Event('LS', patient_number, T + 10, FEL)
            patient_dict[patient_number].current_pos = 'U'
            patient_dict[patient_number].uqt = T - patient_dict[patient_number].s_arrival_time
            patient_dict[patient_number].s_arrival_time = T
        else:
            state_vars['U'] += 1
    else:
        if state_vars['BQ'] > 0:
            state_vars['BQ'] -= 1
            patient_number = Q_lists['BQ']['que'].pop(0)
            Event('LS', patient_number, T + 60, FEL)
            patient_dict[patient_number].current_pos = 'B'
            patient_dict[patient_number].sb = T
            patient_dict[patient_number].bqt = T - patient_dict[patient_number].s_arrival_time
            patient_dict[patient_number].s_arrival_time = T
        else:
            state_vars['B'] += 1

def SE(event):
    global number_of_patient,T,last_T
    patient_number = event.patient
    sur_type = patient_dict[patient_number].surgery_type
    # Forward operations
    if sur_type == 's':
        if state_vars['G'] > 0:  # Available bed in ward
            state_vars['G'] -= 1
            recovery_duration = exponential(General_time)  # Duration in ward
            Event('GE', patient_number, T + recovery_duration, FEL)
            patient_dict[patient_number].current_pos = 'G'
            patient_dict[patient_number].gt += recovery_duration
        else:  # No available bed, wait in GQ
            state_vars['GQ'] += 1
            Q_lists['GQ']['que'].append(patient_number)
            patient_dict[patient_number].current_pos = 'GQ'
            patient_dict[patient_number].s_arrival_time = T
    elif sur_type == 'm':
        re_ty = random.random()  # Type of recovery room
        if re_ty <= 0.7:
            recovery_room = 'ward'
        elif 0.7 < re_ty <= 0.9:
            recovery_room = 'CCU'
        else:
            recovery_room = 'ICU' 
        if recovery_room == 'ICU':
            if state_vars['IC'] > 0:  # Available ICU bed
                state_vars['IC'] -= 1
                recovery_duration = exponential(1/1500)  # Duration in ICU min
                Event('ICE', patient_number, T + recovery_duration, FEL)
                patient_dict[patient_number].current_pos = 'IC'
                patient_dict[patient_number].s_arrival_time = T
                patient_dict[patient_number].icut += recovery_duration
            else:  # No available ICU bed
                state_vars['ICQ'] += 1
                Q_lists['ICQ']['que'].append(patient_number)
                patient_dict[patient_number].current_pos = 'ICQ'
                patient_dict[patient_number].s_arrival_time = T
        elif recovery_room == 'CCU':  # Available CCU bed
            if state_vars['CC'] > 0:
                state_vars['CC'] -= 1
                recovery_duration = exponential(1/1500)  # Duration in CCU
                Event('CCE', patient_number, T + recovery_duration, FEL)
                patient_dict[patient_number].current_pos = 'CC'
                patient_dict[patient_number].s_arrival_time = T
                patient_dict[patient_number].ccut += recovery_duration
            else:  # No available CCU bed
                state_vars['CCQ'] += 1
                Q_lists['CCQ']['que'].append(patient_number)
                patient_dict[patient_number].current_pos = 'CCQ'
                patient_dict[patient_number].s_arrival_time = T
        else:
            if state_vars['G'] > 0:  # Available bed in ward
                state_vars['G'] -= 1
                recovery_duration = exponential(General_time)  # Duration in ward
                Event('GE', patient_number, T + recovery_duration, FEL)
                patient_dict[patient_number].current_pos = 'G'
                patient_dict[patient_number].gt += recovery_duration
            else:  # No available bed, wait in GQ
                state_vars['GQ'] += 1
                Q_lists['GQ']['que'].append(patient_number)
                patient_dict[patient_number].current_pos = 'GQ'
                patient_dict[patient_number].s_arrival_time = T
    else:  # Complex surgery
        #is_dead = False  # Randomly generated
        de = random.random()
        if de <= 0.1:
            is_dead = True
        else:
            is_dead = False
        if not is_dead:
            retry_sur = random.random() # Check if retry surgery is required
            if retry_sur < .01:
                retry_sur = True
            else:
                retry_sur = False
            if not retry_sur:
                heart_sur = random.random()  # Check if operation is a heart surgery
                if heart_sur<.25:
                    heart_sur = True
                else:
                    heart_sur = False
                if not heart_sur:
                    if state_vars['IC'] > 0:  # Available ICU bed
                        state_vars['IC'] -= 1
                        recovery_duration = exponential(1/1500) # Duration in ICU
                        Event('ICE', patient_number, T + recovery_duration, FEL)
                        patient_dict[patient_number].current_pos = 'IC'
                        patient_dict[patient_number].s_arrival_time = T
                        patient_dict[patient_number].icut += recovery_duration
                    else:  # No available ICU bed
                        state_vars['ICQ'] += 1
                        Q_lists['ICQ']['que'].append(patient_number)
                        patient_dict[patient_number].current_pos = 'ICQ'
                        patient_dict[patient_number].s_arrival_time = T

                else:
                    if state_vars['CC'] > 0:  # Available CCU bed
                        state_vars['CC'] -= 1
                        recovery_duration = exponential(1/1500)  # Duration in CCU
                        Event('CCE', patient_number, T + recovery_duration, FEL)
                        patient_dict[patient_number].current_pos = 'CC'
                        patient_dict[patient_number].s_arrival_time = T
                        patient_dict[patient_number].ccut += recovery_duration
                    else:  # No available CCU bed
                        state_vars['CCQ'] += 1
                        Q_lists['CCQ']['que'].append(patient_number)
                        patient_dict[patient_number].current_pos = 'CCQ'
                        patient_dict[patient_number].s_arrival_time = T
            else:  # Retry surgery
                retry_sur_type = 's'  # Type of retry surgery
                if state_vars['S'] > 0:
                    if retry_sur_type == 's':
                        sur_duration = Normal(30.22 , 22.56)  # Duration of simple surgery
                    elif retry_sur_type == 'm':
                        sur_duration = Normal(74.54 , 99.11)  # Duration of medium surgery
                    else:
                        sur_duration = Normal(242.03 , 4003.67)   # Duration of complex surgery
                    state_vars['S'] -= 1
                    Event('SE', patient_number, T + sur_duration, FEL)
                    patient_dict[patient_number].current_pos = 'S'
                    patient_dict[patient_number].st += sur_duration
                    patient_dict[patient_number].sur_counter += 1
                    patient_dict[patient_number].sur_entrance_time = T
                else:  # No available surgery room
                    state_vars['ESQ'] += 1
                    Q_lists['ESQ']['que'].append(patient_number)
                    patient_dict[patient_number].current_pos = 'QS'
                    patient_dict[patient_number].s_arrival_time = T
    # Backward operations
    state_vars['RS'] += 1
    Event('RSE', -1, T + 10, FEL)                  

def RSE(event):
    global number_of_patient,T,last_T
    state_vars['RS'] -= 1
    if((state_vars['ESQ'] == 0)and(state_vars['NSQ'] == 0)):
        state_vars['S'] += 1
    else:
        if(state_vars['ESQ'] > 0):
            state_vars['ESQ'] -= 1
            patient_number = Q_lists['ESQ']['que'].pop(0)
        else:
            state_vars['NSQ'] -= 1
            patient_number = Q_lists['NSQ']['que'].pop(0)
        surgery_type = patient_dict[patient_number].surgery_type
        if(surgery_type == 's'):
            surgery_duration = Normal(30.22 , 22.56) # duration of simple surgery 
        elif(surgery_type == 'm'):
            surgery_duration = Normal(74.54 , 99.11) # duration of medium surgery
        else:
            surgery_duration = Normal(242.03 , 4003.67) # duration of complex surgery
        Event('SE',patient_number,T + surgery_duration,FEL)
        patient_dict[patient_number].current_pos = 'S'
        patient_dict[patient_number].sqt = T - patient_dict[patient_number].s_arrival_time
        patient_dict[patient_number].st += surgery_duration

def GE(event):
    global number_of_patient,T,last_T
    patient_number = event.patient
    patient_dict[patient_number].current_pos = 'Ex'
    patient_dict[patient_number].s_arrival_time = T
    patient_dict[patient_number].departure = T
    if(state_vars['GQ'] != 0):
        state_vars['GQ'] -= 1
        patient_number = Q_lists['GQ']['que'].pop(0)
        patient_dict[patient_number].current_pos = 'G'
        patient_dict[patient_number].gqt = T - patient_dict[patient_number].s_arrival_time
        patient_dict[patient_number].s_arrival_time = T
        recovery_duration = exponential(General_time) # ward recovery duration.
        patient_dict[patient_number].gt += recovery_duration
        Event('GE',patient_number,T + recovery_duration,FEL)
    else:
        state_vars['G'] += 1

def ICE(event):
    global number_of_patient,T,last_T
    patient_number = event.patient
    #forward
    if(state_vars['G']>0):
        state_vars['G'] -= 1
        patient_dict[patient_number].current_pos = 'G'
        patient_dict[patient_number].s_arrival_time = T
        recovery_duration = exponential(General_time)# ward recovery duration 
        patient_dict[patient_number].gt += recovery_duration
        Event('GE',patient_number,T + recovery_duration,FEL)
    else:
        state_vars['GQ']+=1
        Q_lists['GQ']['que'].append(patient_number)
        patient_dict[patient_number].current_pos = 'GQ'
        patient_dict[patient_number].s_arrival_time = T 
    #backward
    if(state_vars['ICQ'] > 0):
        state_vars['ICQ'] -= 1
        patient_number = Q_lists['ICQ']['que'].pop(0)
        patient_dict[patient_number].current_pos = 'IC'
        patient_dict[patient_number].icuqt = T - patient_dict[patient_number].s_arrival_time
        patient_dict[patient_number].s_arrival_time = T
        recovery_duration = exponential(1/1500) # ICU recovery time
        patient_dict[patient_number].icut += recovery_duration
        Event('ICE',patient_number,T + recovery_duration,FEL)
    else:
        state_vars['IC'] += 1

def CCE(event):
    global number_of_patient,T,last_T
    patient_number = event.patient
    #forward
    if(state_vars['G']>0):
        state_vars['G'] -= 1
        patient_dict[patient_number].current_pos = 'G'
        patient_dict[patient_number].s_arrival_time = T
        recovery_duration = exponential(General_time) # ward recovery duration 
        patient_dict[patient_number].gt += recovery_duration
        Event('GE',patient_number,T + recovery_duration,FEL)
    else:
        state_vars['GQ']+=1
        Q_lists['GQ']['que'].append(patient_number)
        patient_dict[patient_number].current_pos = 'GQ'
        patient_dict[patient_number].s_arrival_time = T 
    #backward
    if(state_vars['CCQ']>0):
        state_vars['CCQ'] -= 1
        patient_number = Q_lists['CCQ']['que'].pop(0)
        patient_dict[patient_number].current_pos = 'CCU'
        patient_dict[patient_number].ccuqt = T - patient_dict[patient_number].s_arrival_time
        patient_dict[patient_number].s_arrival_time = T
        recovery_duration = exponential(1/1500) # CCU recovery time 
        patient_dict[patient_number].ccut += recovery_duration
        Event('CCE',patient_number,T + recovery_duration, FEL)
    else:
        state_vars['CC'] += 1

def NICE(event):
    global number_of_patient,T,last_T
    patient_number = event.patient
    if(state_vars['G']>0):
        state_vars['G'] -= 1
        patient_dict[patient_number].current_pos = 'G'
        patient_dict[patient_number].s_arrival_time = T
        recovery_duration = exponential(General_time) #ward recovery duration 
        patient_dict[patient_number].gt += recovery_duration
        Event('GE',patient_number,T + recovery_duration,FEL)
    else:
        state_vars['GQ']+=1
        Q_lists['GQ']['que'].append(patient_number)
        patient_dict[patient_number].current_pos = 'GQ'
        patient_dict[patient_number].s_arrival_time = T
    state_vars['NIC'] += 1

def NCCE(event):
    global number_of_patient,T,last_T
    patient_number = event.patient
    if(state_vars['G']>0):
        state_vars['G'] -= 1
        patient_dict[patient_number].current_pos = 'G'
        patient_dict[patient_number].s_arrival_time = T
        recovery_duration = exponential(General_time) # ward recovery duration 
        patient_dict[patient_number].gt += recovery_duration
        Event('GE',patient_number,T + recovery_duration,FEL)
    else:
        state_vars['GQ']+=1
        Q_lists['GQ']['que'].append(patient_number)
        patient_dict[patient_number].current_pos = 'GQ'
        patient_dict[patient_number].s_arrival_time = T

    state_vars['NCC'] += 1


def NSP():
    if(state_vars['IC']>=1):
        if(state_vars['IC']>=2):
            #Two beds of ICU should be disablesd 
            state_vars['IC'] -= 2
            state_vars['NIC'] += 2
        else:
            event_index = find_earliest_event('ICE')
            if(FEL[event_index].time - T < 24*60):
                #change this event as NICE.
                FEL[event_index].type = 'NICE'
            else:
                state_vars['IC'] -= 1
                state_vars['NIC']+=1
    else:
        event_index = find_earliest_event('ICE')
        if(FEL[event_index].time - T < 24*60):
            #change the event type from ICE to NICE
            FEL[event_index].type = 'NICE'
            event_index = find_earliest_event('ICE')
            if(FEL[event_index].time - T < 24*60):
                #change the event type from ICE to NICE
                FEL[event_index].type = 'NICE'
    if(state_vars['CC']>=1):
        state_vars['CC'] -= 1
        state_vars['NCC'] += 1 
    else:
        event_index = find_earliest_event('CCE')
        if(event_index - T < 24*60):
            # change the event type form CCE to NCCE
            FEL[event_index].type = 'NCCE'
    Event('NEP',-1,T + 24*60,FEL)

def NEP():
    if(state_vars['NIC'] == 2):
        if(state_vars['ICQ'] == 0):
            state_vars['IC'] += 2
        elif(state_vars['ICQ'] == 1):
            state_vars['IC'] += 1
            state_vars['ICQ'] -= 1
            patient_number = Q_lists['ICQ']['que'].pop(0)
            patient_dict[patient_number].current_pos = 'IC'
            patient_dict[patient_number].icuqt = T - patient_dict[patient_number].s_arrival_time
            patient_dict[patient_number].s_arrival_time = T
            recovery_duration = exponential(1/1500) # ICU recovery time
            patient_dict[patient_number].icut += recovery_duration
            Event('ICE',patient_number,T + recovery_duration,FEL)
        else:
            state_vars['ICQ'] -= 2
            #first person in Que
            patient_number = Q_lists['ICQ']['que'].pop(0)
            patient_dict[patient_number].current_pos = 'IC'
            patient_dict[patient_number].icuqt = T - patient_dict[patient_number].s_arrival_time
            patient_dict[patient_number].s_arrival_time = T
            recovery_duration = exponential(1/1500) # ICU recovery time
            patient_dict[patient_number].icut += recovery_duration
            Event('ICE',patient_number,T + recovery_duration,FEL)
            #second persion in Que
            patient_number = Q_lists['ICQ']['que'].pop(0)
            patient_dict[patient_number].current_pos = 'IC'
            patient_dict[patient_number].icuqt = T - patient_dict[patient_number].s_arrival_time
            patient_dict[patient_number].s_arrival_time = T
            recovery_duration = exponential(1/1500) # ICU recovery time
            patient_dict[patient_number].icut += recovery_duration
            Event('ICE',patient_number,T + recovery_duration,FEL)
    elif(state_vars['NIC'] == 1):
        if(state_vars['ICQ'] > 0):
            state_vars['ICQ'] -= 1
            patient_number = Q_lists['ICQ']['que'].pop(0)
            patient_dict[patient_number].current_pos = 'IC'
            patient_dict[patient_number].icuqt = T - patient_dict[patient_number].s_arrival_time
            patient_dict[patient_number].s_arrival_time = T
            recovery_duration = exponential(1/1500) # ICU recovery time
            patient_dict[patient_number].icut += recovery_duration
            Event('ICE',patient_number,T + recovery_duration,FEL) 
        else:
            state_vars['IC'] += 1
    state_vars['NIC'] = 0
    if(state_vars['NCC'] == 1):
        if(state_vars['CCQ'] > 0 ):
            state_vars['CCQ'] -= 1
            patient_number = Q_lists['CCQ']['que'].pop(0)
            patient_dict[patient_number].current_pos = 'CCU'
            patient_dict[patient_number].ccuqt = T - patient_dict[patient_number].s_arrival_time
            patient_dict[patient_number].s_arrival_time = T
            recovery_duration = exponential(1/1500) # CCU recovery time 
            patient_dict[patient_number].ccut += recovery_duration
            Event('CCE',patient_number,T + recovery_duration, FEL)
        else:
            state_vars['CC'] += 1
    state_vars['NCC'] = 0

def extract_queue_data(Q_lists,stats): 

    for key, value in Q_lists.items():
        stats[f"{key}_avg"] = value['avg']
        stats[f"{key}_max"] = value['max'] 
    return stats                         

def find_earliest_event(event_type):
    for i in range(len(FEL)):
        print(FEL[i].type)
        if(FEL[i].type == event_type):
            return i
    return None

def create_df(start,end,pl_list):
    BQT = 0
    for pl in pl_list:
        if(pl.sbq == 0):
            continue
        if(start<=pl.sb and pl.sb<=end):
            if(start<= pl.sbq):
                BQT += pl.sb - pl.sbq
            else:
                BQT += pl.sb - start
        elif(0<pl.sbq and pl.sbq<start):
            if(pl.sb == 0 or pl.sb>end):
                BQT += end - start
        elif(pl.sbq>=start and (pl.sb == 0 or pl.sb>end)):
             BQT += end - pl.sbq
    BQ = BQT/(end - start)
    return (BQT,BQ)
            
        


def simulation(simulation_time):
    tf_time = 6
    #FEL = []
    df_set = {}
    global number_of_patient,T,last_T,FEL
    number_of_patient = 0
    T = 0
    last_T = 0
    #daily power outage check
    for i in range(30):
        outage = False if random.random() > 1/30 else True
        Event('daily_check',outage,i*24*60,FEL)
    for i in range(1,1000):
        Event('create_df',-1,i*tf_time*60,FEL)
    Event('END',-1,simulation_time,FEL)
    EST = exponential(1/15)
    NST = exponential(1/60)
    Event('ES', -1,EST, FEL)
    Event('NS', -1,NST , FEL)
    T = 0
    print(f'first E_patient arrival time:{EST}\nfirst N_patient arrival time:{NST}')
    #print(number_of_patient)
    print('len of FEL',len(FEL),'FEL components:')
    for i in FEL:
        print(i.type,i.time)
    print('initial state:',state_vars)
    stored_data = []#list of dicts to store current event, current time, current state vars and next event. 
    while T < simulation_time:
        current_event = FEL[0]  
        last_T = T
        T = current_event.time 
        print(f"current event type:{current_event.type} ,length of FEL:{len(FEL)} current time:{T} last time:{last_T}")
        ls = FEL.pop(0) 
        if T <= simulation_time:  
            update_cumulative_stats()
            snap_shot = {}
            snap_shot['T'] = T
            snap_shot['current_event'] = current_event.type
            if(current_event.type == 'create_df'):
                df_set[round(T/(tf_time*60))] = create_df(T - tf_time*60,T,list(patient_dict.values()))
            elif current_event.type == 'daily_check':
                if(current_event.patient):
                    NSP()        
            elif current_event.type == 'ES':
                ES()
            elif current_event.type == 'NS':
                NS()
            elif current_event.type == 'LS':
                LS(current_event)
            elif current_event.type == 'LE':
                LE(current_event)
            elif current_event.type == 'SS':
                SS(current_event)
            elif current_event.type == 'SE':
                SE(current_event)
            elif current_event.type == 'RSE':
                RSE(current_event)
            elif current_event.type == 'GE':
                clear_output()
                GE(current_event)
            elif current_event.type == 'ICE':
                ICE(current_event)
            elif current_event.type == 'NICE':
                NICE(current_event)
            elif current_event.type == 'CCE':
                CCE(current_event)
            elif current_event.type == 'NCCE':
                NCCE(current_event)
            elif current_event.type == 'NEP':
                NEP()
            elif current_event.type == 'END':
                continue
            else:
                raise Exception('some error!')
            for key,value in zip(state_vars.keys(),state_vars.values()):
                snap_shot[key] = value
            for key in stats:
                snap_shot[key] = stats[key]
            snap_shot['next_event'] = FEL[0].type
            snap_shot['FEL'] = [i.type for i in FEL]
            stored_data.append(snap_shot)
        else:
            print(current_event.type)
            print(T)
        print(f"state_vars:{state_vars}")
        print(f'current event:{ls.type}. current FEL order!')
        for i in FEL:
            print(i.type , i.time)
            #FEL.clear()
        #print(state_vars ,current_event)
    print('-------------------------------------------------------------------------------------------------')
    print('Simulation Ended!')
    return stored_data,df_set


# for i in range(5):
#     state_vars = {'U':10,'UQ':0,'B':25,'BQ':0,'L':3,'ELQ':0,'NLQ':0,'S':50,'ESQ':0,'NSQ':0,'RS':0,'G':40,'GQ':0,'IC':10,'NIC':0,'ICQ':0,'CC':5,'NCC':0,'CCQ':0}
#     type_of_events = ['ES','NS','LS','LE','SS','SE','RSE','GE','IC','NIC','CCE','NCCE','NS','NE']
#     Q_lists = { 'UQ': {'que': [], 'avg': 0, 'max': 0}, 'BQ': {'que': [], 'avg': 0, 'max': 0},
#                 'ELQ': {'que': [], 'avg': 0, 'max': 0}, 'NLQ': {'que': [], 'avg': 0, 'max': 0},
#                 'ESQ': {'que': [], 'avg': 0, 'max': 0}, 'NSQ': {'que': [], 'avg': 0, 'max': 0}, 
#                 'GQ': {'que': [], 'avg': 0, 'max': 0}, 'ICQ': {'que': [], 'avg': 0, 'max': 0}, 
#                 'CCQ': {'que': [], 'avg': 0, 'max': 0} }
#     patient_dict = {} # List of Patient objects that have entered the system
#     stats = {'fully_u':0,'eff_u':0,'eff_b':0,'eff_l':0,'eff_s':0,'eff_g':0,'eff_icu':0,'eff_ccu':0}
#     patient_pos = ['U','UQ','B','BQ','L','LQ','S','SQ','G','GQ','ICU','ICUQ','CCU','CCUQ']
#     FEL = []
#     data = simulation(5000)
#     data_df = pd.DataFrame(data)
#     # Load the existing workbook and append the new data
#     patient_data = [i.get_values() for i in patient_dict.values()]
#     patient_df = pd.DataFrame(patient_data)
#     extract_queue_data(Q_lists,stats)
#     stats_df = pd.Series(stats)
#     has_left_patient = patient_df[patient_df['departure']>0]
#     stats_df['avg_system_dur'] = (has_left_patient['departure']- has_left_patient['arrival_time']).mean()
#     stats_df['sur_avg_complex'] = patient_df[(patient_df['surgery_type'] == 'c')|(patient_df['sur_counter']>1)]['sur_counter'].mean()
#     stats_df['more_than_24h'] = (patient_df[patient_df['type']=='N'][['uqt','bqt','lqt','sqt','gqt','icuqt','ccuqt']].sum(axis = 1) > 24*60).sum()/patient_df[patient_df['type']=='N'].shape[0]
#     with pd.ExcelWriter('sample1.xlsx', engine='openpyxl', mode='a') as writer:  
#         data_df.to_excel(writer, sheet_name = f'Rep{i+1}', index=False)
#         patient_df.to_excel(writer, sheet_name = f'Patients_Rep{i+1}',index=False )
#         stats_df.to_excel(writer, sheet_name = f'Rep{i+1}_stats',index = True)
#     time.sleep(1)
General_time =  1/3000  
from IPython.display import clear_output

# %%
#sensitivity analyse:
a = pd.DataFrame({'l':[4,5,6],'rep':[1,2,3]})
file_name = 'excel_data_systems1tf.xlsx'
a.to_excel(file_name)
rep_count = 15
BQ_dict = {}
BQT_dict= {}
data_df_dict = {}
patient_df_dict = {}
stats_df_dict = {}
for l in [5]:
    for i in range(rep_count):
        clear_output()
        time.sleep(1)
        state_vars = {'U':10,'UQ':0,'B':25,'BQ':0,'L':l,'ELQ':0,'NLQ':0,'S':20,'ESQ':0,'NSQ':0,'RS':0,'G':60,'GQ':0,'IC':10,'NIC':0,'ICQ':0,'CC':5,'NCC':0,'CCQ':0}
        type_of_events = ['ES','NS','LS','LE','SS','SE','RSE','GE','IC','NIC','CCE','NCCE','NS','NE']
        Q_lists = { 'UQ': {'que': [], 'avg': 0, 'max': 0}, 'BQ': {'que': [], 'avg': 0, 'max': 0},
                    'ELQ': {'que': [], 'avg': 0, 'max': 0}, 'NLQ': {'que': [], 'avg': 0, 'max': 0},
                    'ESQ': {'que': [], 'avg': 0, 'max': 0}, 'NSQ': {'que': [], 'avg': 0, 'max': 0}, 
                    'GQ': {'que': [], 'avg': 0, 'max': 0}, 'ICQ': {'que': [], 'avg': 0, 'max': 0}, 
                    'CCQ': {'que': [], 'avg': 0, 'max': 0} }
        patient_dict = {} # List of Patient objects that have entered the system
        stats = {'fully_u':0,'eff_u':0,'eff_b':0,'eff_l':0,'eff_s':0,'eff_g':0,'eff_icu':0,'eff_ccu':0}
        patient_pos = ['U','UQ','B','BQ','L','LQ','S','SQ','G','GQ','ICU','ICUQ','CCU','CCUQ']
        FEL = []
        data,df_set = simulation(100000)
        df_set = pd.DataFrame(df_set).T
        BQT_dict[i] = df_set[0]
        BQ_dict[i] = df_set[1]
        data_df = pd.DataFrame(data)
        # Load the existing workbook and append the new data
        patient_data = [i.get_values() for i in patient_dict.values()]
        patient_df = pd.DataFrame(patient_data)
        extract_queue_data(Q_lists,stats)
        stats_df = pd.Series(stats)
        has_left_patient = patient_df[patient_df['departure']>0]
        stats_df['avg_system_dur'] = (has_left_patient['departure']- has_left_patient['arrival_time']).mean()
        stats_df['sur_avg_complex'] = patient_df[(patient_df['surgery_type'] == 'c')|(patient_df['sur_counter']>1)]['sur_counter'].mean()
        stats_df['more_than_24h'] = (patient_df[patient_df['type']=='N'][['uqt','bqt','lqt','sqt','gqt','icuqt','ccuqt']].sum(axis = 1) > 24*60).sum()/patient_df[patient_df['type']=='N'].shape[0]
        with pd.ExcelWriter(file_name, engine='openpyxl', mode='a') as writer:  
            # data_df.to_excel(writer, sheet_name = f'L{l}Rep{i+1}', index=False)
            # patient_df.to_excel(writer, sheet_name = f'L{l}Patients_Rep{i+1}',index=False )
            # stats_df.to_excel(writer, sheet_name = f'L{l}Rep{i+1}_stats',index = True)
            data_df_dict[f'{l}_{i}'] = data_df
            patient_df_dict[f'{l}_{i}'] = patient_df
            stats_df_dict[f'{l}_{i}'] = stats_df
        time.sleep(1)
# Out:
# state_vars:{'U': 10, 'UQ': 0, 'B': 0, 'BQ': 4, 'L': 5, 'ELQ': 0, 'NLQ': 0, 'S': 20, 'ESQ': 0, 'NSQ': 0, 'RS': 0, 'G': 0, 'GQ': 26, 'IC': 8, 'NIC': 0, 'ICQ': 0, 'CC': 1, 'NCC': 0, 'CCQ': 0}
# current event:GE. current FEL order!
# END 100000
# NS 100012.64288074058
# NS 100029.59596664285
# GE 100034.44484269242
# create_df 100080
# GE 100081.93279874332
# GE 100117.28532513743
# GE 100126.58913141827
# SS 100126.9813371323
# GE 100132.4426039032
# SS 100203.96248501283
# GE 100206.80414369615
# CCE 100306.97610803021
# SS 100309.83526754723
# ICE 100332.1465897992
# GE 100336.18840637227
# GE 100343.33507990795
# SS 100358.08247848542
# GE 100369.11374457873
# SS 100423.39120206107
# create_df 100440
# SS 100451.06897867341
# SS 100498.20458807888
# SS 100513.97491752524
# SS 100625.79499524913
# GE 100626.97143258009
# SS 100628.7049264073
# SS 100686.11882382962
# SS 100734.63296110307
# SS 100749.25246034988
# SS 100768.13492920171
# GE 100777.7651779212
# create_df 100800
# GE 101014.57661246233
# GE 101091.73943845378
# create_df 101160
# GE 101182.96173233158
# SS 101200.7950841942
# GE 101215.61132746554
# SS 101246.98051413916
# GE 101247.50479003313
# SS 101255.15908081837
# SS 101260.306384256
# SS 101263.9307409817
# SS 101273.69906902494
# GE 101313.63824601882
# SS 101328.41241267307
# SS 101329.71832617137
# SS 101332.15822388612
# SS 101359.84063687334
# GE 101384.51191961908
# CCE 101392.95988679139
# SS 101417.32700751892
# GE 101502.7123910223
# create_df 101520
# GE 101541.34150776792
# GE 101549.76737323066
# GE 101551.1400461901
# GE 101747.26509137735
# GE 101792.66052949704
# create_df 101880
# GE 101903.77470660013
# GE 101930.02173519079
# GE 101999.90946603946
# ICE 102054.11819513081
# GE 102078.27260456492
# GE 102078.97803935755
# GE 102143.37466729744
# create_df 102240
# GE 102367.2018306088
# GE 102420.45881330552
# GE 102427.3087183582
# GE 102431.47062451165
# GE 102496.8029979511
# GE 102559.1378235142
# create_df 102600
# GE 102617.12950815192
# GE 102719.74858920944
# GE 102935.11341224574
# create_df 102960
# GE 103026.50777002313
# GE 103100.12383992907
# create_df 103320
# GE 103335.37267693628
# GE 103382.49900350865
# GE 103442.25897184548
# GE 103502.9660208191
# create_df 103680
# GE 103891.43045059149
# create_df 104040
# GE 104143.28343795224
# GE 104290.45637234166
# create_df 104400
# GE 104440.60107464611
# GE 104673.23664053628
# create_df 104760
# GE 105000.3326331474
# create_df 105120
# GE 105226.35482550117
# create_df 105480
# CCE 105487.81412026884
# create_df 105840
# create_df 106200
# create_df 106560
# GE 106634.93646580398
# create_df 106920
# CCE 107059.24450834886
# GE 107163.08995096775
# create_df 107280
# GE 107321.94518184272
# create_df 107640
# create_df 108000
# create_df 108360
# create_df 108720
# create_df 109080
# GE 109282.03853693651
# create_df 109440
# create_df 109800
# create_df 110160
# create_df 110520
# GE 110650.67575184825
# GE 110828.42792024915
# create_df 110880
# GE 111147.49919255066
# create_df 111240
# create_df 111600
# create_df 111960
# create_df 112320
# create_df 112680
# create_df 113040
# create_df 113400
# create_df 113760
# create_df 114120
# create_df 114480
# create_df 114840
# create_df 115200
# create_df 115560
# create_df 115920
# create_df 116280
# create_df 116640
# create_df 117000
# create_df 117360
# create_df 117720
# create_df 118080
# create_df 118440
# create_df 118800
# GE 118990.42057830164
# create_df 119160
# create_df 119520
# create_df 119880
# create_df 120240
# create_df 120600
# create_df 120960
# create_df 121320
# create_df 121680
# create_df 122040
# create_df 122400
# create_df 122760
# create_df 123120
# create_df 123480
# create_df 123840
# create_df 124200
# create_df 124560
# create_df 124920
# create_df 125280
# create_df 125640
# create_df 126000
# create_df 126360
# create_df 126720
# create_df 127080
# create_df 127440
# create_df 127800
# create_df 128160
# create_df 128520
# create_df 128880
# create_df 129240
# create_df 129600
# create_df 129960
# create_df 130320
# create_df 130680
# create_df 131040
# create_df 131400
# create_df 131760
# create_df 132120
# create_df 132480
# create_df 132840
# create_df 133200
# create_df 133560
# create_df 133920
# create_df 134280
# create_df 134640
# create_df 135000
# create_df 135360
# create_df 135720
# create_df 136080
# create_df 136440
# create_df 136800
# create_df 137160
# create_df 137520
# create_df 137880
# create_df 138240
# create_df 138600
# create_df 138960
# create_df 139320
# create_df 139680
# create_df 140040
# create_df 140400
# create_df 140760
# create_df 141120
# create_df 141480
# create_df 141840
# create_df 142200
# create_df 142560
# create_df 142920
# create_df 143280
# create_df 143640
# create_df 144000
# create_df 144360
# create_df 144720
# create_df 145080
# create_df 145440
# create_df 145800
# create_df 146160
# create_df 146520
# create_df 146880
# create_df 147240
# create_df 147600
# create_df 147960
# create_df 148320
# create_df 148680
# create_df 149040
# create_df 149400
# create_df 149760
# create_df 150120
# create_df 150480
# create_df 150840
# create_df 151200
# create_df 151560
# create_df 151920
# create_df 152280
# create_df 152640
# create_df 153000
# create_df 153360
# create_df 153720
# create_df 154080
# create_df 154440
# create_df 154800
# create_df 155160
# create_df 155520
# create_df 155880
# create_df 156240
# create_df 156600
# create_df 156960
# create_df 157320
# create_df 157680
# create_df 158040
# create_df 158400
# create_df 158760
# create_df 159120
# create_df 159480
# create_df 159840
# create_df 160200
# create_df 160560
# create_df 160920
# create_df 161280
# create_df 161640
# create_df 162000
# create_df 162360
# create_df 162720
# create_df 163080
# create_df 163440
# create_df 163800
# create_df 164160
# create_df 164520
# create_df 164880
# create_df 165240
# create_df 165600
# create_df 165960
# create_df 166320
# create_df 166680
# create_df 167040
# create_df 167400
# create_df 167760
# create_df 168120
# create_df 168480
# create_df 168840
# create_df 169200
# create_df 169560
# create_df 169920
# create_df 170280
# create_df 170640
# create_df 171000
# create_df 171360
# create_df 171720
# create_df 172080
# create_df 172440
# create_df 172800
# create_df 173160
# create_df 173520
# create_df 173880
# create_df 174240
# create_df 174600
# create_df 174960
# create_df 175320
# create_df 175680
# create_df 176040
# create_df 176400
# create_df 176760
# create_df 177120
# create_df 177480
# create_df 177840
# create_df 178200
# create_df 178560
# create_df 178920
# create_df 179280
# create_df 179640
# create_df 180000
# create_df 180360
# create_df 180720
# create_df 181080
# create_df 181440
# create_df 181800
# create_df 182160
# create_df 182520
# create_df 182880
# create_df 183240
# create_df 183600
# create_df 183960
# create_df 184320
# create_df 184680
# create_df 185040
# create_df 185400
# create_df 185760
# create_df 186120
# create_df 186480
# create_df 186840
# create_df 187200
# create_df 187560
# create_df 187920
# create_df 188280
# create_df 188640
# create_df 189000
# create_df 189360
# create_df 189720
# create_df 190080
# create_df 190440
# create_df 190800
# create_df 191160
# create_df 191520
# create_df 191880
# create_df 192240
# create_df 192600
# create_df 192960
# create_df 193320
# create_df 193680
# create_df 194040
# create_df 194400
# create_df 194760
# create_df 195120
# create_df 195480
# create_df 195840
# create_df 196200
# create_df 196560
# create_df 196920
# create_df 197280
# create_df 197640
# create_df 198000
# create_df 198360
# create_df 198720
# create_df 199080
# create_df 199440
# create_df 199800
# create_df 200160
# create_df 200520
# create_df 200880
# create_df 201240
# create_df 201600
# create_df 201960
# create_df 202320
# create_df 202680
# create_df 203040
# create_df 203400
# create_df 203760
# create_df 204120
# create_df 204480
# create_df 204840
# create_df 205200
# create_df 205560
# create_df 205920
# create_df 206280
# create_df 206640
# create_df 207000
# create_df 207360
# create_df 207720
# create_df 208080
# create_df 208440
# create_df 208800
# create_df 209160
# create_df 209520
# create_df 209880
# create_df 210240
# create_df 210600
# create_df 210960
# create_df 211320
# create_df 211680
# create_df 212040
# create_df 212400
# create_df 212760
# create_df 213120
# create_df 213480
# create_df 213840
# create_df 214200
# create_df 214560
# create_df 214920
# create_df 215280
# create_df 215640
# create_df 216000
# create_df 216360
# create_df 216720
# create_df 217080
# create_df 217440
# create_df 217800
# create_df 218160
# create_df 218520
# create_df 218880
# create_df 219240
# create_df 219600
# create_df 219960
# create_df 220320
# create_df 220680
# create_df 221040
# create_df 221400
# create_df 221760
# create_df 222120
# create_df 222480
# create_df 222840
# create_df 223200
# create_df 223560
# create_df 223920
# create_df 224280
# create_df 224640
# create_df 225000
# create_df 225360
# create_df 225720
# create_df 226080
# create_df 226440
# create_df 226800
# create_df 227160
# create_df 227520
# create_df 227880
# create_df 228240
# create_df 228600
# create_df 228960
# create_df 229320
# create_df 229680
# create_df 230040
# create_df 230400
# create_df 230760
# create_df 231120
# create_df 231480
# create_df 231840
# create_df 232200
# create_df 232560
# create_df 232920
# create_df 233280
# create_df 233640
# create_df 234000
# create_df 234360
# create_df 234720
# create_df 235080
# create_df 235440
# create_df 235800
# create_df 236160
# create_df 236520
# create_df 236880
# create_df 237240
# create_df 237600
# create_df 237960
# create_df 238320
# create_df 238680
# create_df 239040
# create_df 239400
# create_df 239760
# create_df 240120
# create_df 240480
# create_df 240840
# create_df 241200
# create_df 241560
# create_df 241920
# create_df 242280
# create_df 242640
# create_df 243000
# create_df 243360
# create_df 243720
# create_df 244080
# create_df 244440
# create_df 244800
# create_df 245160
# create_df 245520
# create_df 245880
# create_df 246240
# create_df 246600
# create_df 246960
# create_df 247320
# create_df 247680
# create_df 248040
# create_df 248400
# create_df 248760
# create_df 249120
# create_df 249480
# create_df 249840
# create_df 250200
# create_df 250560
# create_df 250920
# create_df 251280
# create_df 251640
# create_df 252000
# create_df 252360
# create_df 252720
# create_df 253080
# create_df 253440
# create_df 253800
# create_df 254160
# create_df 254520
# create_df 254880
# create_df 255240
# create_df 255600
# create_df 255960
# create_df 256320
# create_df 256680
# create_df 257040
# create_df 257400
# create_df 257760
# create_df 258120
# create_df 258480
# create_df 258840
# create_df 259200
# create_df 259560
# create_df 259920
# create_df 260280
# create_df 260640
# create_df 261000
# create_df 261360
# create_df 261720
# create_df 262080
# create_df 262440
# create_df 262800
# create_df 263160
# create_df 263520
# create_df 263880
# create_df 264240
# create_df 264600
# create_df 264960
# create_df 265320
# create_df 265680
# create_df 266040
# create_df 266400
# create_df 266760
# create_df 267120
# create_df 267480
# create_df 267840
# create_df 268200
# create_df 268560
# create_df 268920
# create_df 269280
# create_df 269640
# create_df 270000
# create_df 270360
# create_df 270720
# create_df 271080
# create_df 271440
# create_df 271800
# create_df 272160
# create_df 272520
# create_df 272880
# create_df 273240
# create_df 273600
# create_df 273960
# create_df 274320
# create_df 274680
# create_df 275040
# create_df 275400
# create_df 275760
# create_df 276120
# create_df 276480
# create_df 276840
# create_df 277200
# create_df 277560
# create_df 277920
# create_df 278280
# create_df 278640
# create_df 279000
# create_df 279360
# create_df 279720
# create_df 280080
# create_df 280440
# create_df 280800
# create_df 281160
# create_df 281520
# create_df 281880
# create_df 282240
# create_df 282600
# create_df 282960
# create_df 283320
# create_df 283680
# create_df 284040
# create_df 284400
# create_df 284760
# create_df 285120
# create_df 285480
# create_df 285840
# create_df 286200
# create_df 286560
# create_df 286920
# create_df 287280
# create_df 287640
# create_df 288000
# create_df 288360
# create_df 288720
# create_df 289080
# create_df 289440
# create_df 289800
# create_df 290160
# create_df 290520
# create_df 290880
# create_df 291240
# create_df 291600
# create_df 291960
# create_df 292320
# create_df 292680
# create_df 293040
# create_df 293400
# create_df 293760
# create_df 294120
# create_df 294480
# create_df 294840
# create_df 295200
# create_df 295560
# create_df 295920
# create_df 296280
# create_df 296640
# create_df 297000
# create_df 297360
# create_df 297720
# create_df 298080
# create_df 298440
# create_df 298800
# create_df 299160
# create_df 299520
# create_df 299880
# create_df 300240
# create_df 300600
# create_df 300960
# create_df 301320
# create_df 301680
# create_df 302040
# create_df 302400
# create_df 302760
# create_df 303120
# create_df 303480
# create_df 303840
# create_df 304200
# create_df 304560
# create_df 304920
# create_df 305280
# create_df 305640
# create_df 306000
# create_df 306360
# create_df 306720
# create_df 307080
# create_df 307440
# create_df 307800
# create_df 308160
# create_df 308520
# create_df 308880
# create_df 309240
# create_df 309600
# create_df 309960
# create_df 310320
# create_df 310680
# create_df 311040
# create_df 311400
# create_df 311760
# create_df 312120
# create_df 312480
# create_df 312840
# create_df 313200
# create_df 313560
# create_df 313920
# create_df 314280
# create_df 314640
# create_df 315000
# create_df 315360
# create_df 315720
# create_df 316080
# create_df 316440
# create_df 316800
# create_df 317160
# create_df 317520
# create_df 317880
# create_df 318240
# create_df 318600
# create_df 318960
# create_df 319320
# create_df 319680
# create_df 320040
# create_df 320400
# create_df 320760
# create_df 321120
# create_df 321480
# create_df 321840
# create_df 322200
# create_df 322560
# create_df 322920
# create_df 323280
# create_df 323640
# create_df 324000
# create_df 324360
# create_df 324720
# create_df 325080
# create_df 325440
# create_df 325800
# create_df 326160
# create_df 326520
# create_df 326880
# create_df 327240
# create_df 327600
# create_df 327960
# create_df 328320
# create_df 328680
# create_df 329040
# create_df 329400
# create_df 329760
# create_df 330120
# create_df 330480
# create_df 330840
# create_df 331200
# create_df 331560
# create_df 331920
# create_df 332280
# create_df 332640
# create_df 333000
# create_df 333360
# create_df 333720
# create_df 334080
# create_df 334440
# create_df 334800
# create_df 335160
# create_df 335520
# create_df 335880
# create_df 336240
# create_df 336600
# create_df 336960
# create_df 337320
# create_df 337680
# create_df 338040
# create_df 338400
# create_df 338760
# create_df 339120
# create_df 339480
# create_df 339840
# create_df 340200
# create_df 340560
# create_df 340920
# create_df 341280
# create_df 341640
# create_df 342000
# create_df 342360
# create_df 342720
# create_df 343080
# create_df 343440
# create_df 343800
# create_df 344160
# create_df 344520
# create_df 344880
# create_df 345240
# create_df 345600
# create_df 345960
# create_df 346320
# create_df 346680
# create_df 347040
# create_df 347400
# create_df 347760
# create_df 348120
# create_df 348480
# create_df 348840
# create_df 349200
# create_df 349560
# create_df 349920
# create_df 350280
# create_df 350640
# create_df 351000
# create_df 351360
# create_df 351720
# create_df 352080
# create_df 352440
# create_df 352800
# create_df 353160
# create_df 353520
# create_df 353880
# create_df 354240
# create_df 354600
# create_df 354960
# create_df 355320
# create_df 355680
# create_df 356040
# create_df 356400
# create_df 356760
# create_df 357120
# create_df 357480
# create_df 357840
# create_df 358200
# create_df 358560
# create_df 358920
# create_df 359280
# create_df 359640
# current event type:END ,length of FEL:816 current time:100000 last time:99988.34747885754
# -------------------------------------------------------------------------------------------------
# Simulation Ended!

# %%
BQ_df = pd.DataFrame(BQ_dict)
BQ_df['avg'] = BQ_df.mean(axis = 1)
BQ_df['ma'] = moving_average(BQ_df['avg'].to_list())

BQT_df = pd.DataFrame(BQT_dict)
BQT_df['avg'] = BQT_df.mean(axis = 1)
BQT_df['ma'] = moving_average(BQT_df['avg'].to_list())

# %%
BQ_df.to_pickle('BQ_dfsys1_2.pickle')
BQT_df.to_pickle('BQT_dfsys1_2.pickle')

# %%
def moving_average(ls):
    res = []
    res.append((ls[0]+ls[1])/2)
    for i in range(1,len(ls)-1):
        res.append((ls[i-1]+ls[i]+ls[i+1])/3)
    res.append((ls[-1]+ls[-2])/2)
    return res

# %%
import matplotlib.pyplot as plt

def plotting(BQ_df, col1, col2, title):
    plt.figure(figsize=(15, 5))
    plt.plot(BQ_df.index, BQ_df[col1], linewidth=10, color='red', label='Average across reps')
    plt.plot(BQ_df.index, BQ_df[col2], color='black',linewidth = 2, label='Moving Average')
    for i in BQ_df.columns:
        if(type(i) == int):
            plt.plot(BQ_df.index, BQ_df[i],linewidth = 1)

        
    plt.xlabel('Index')
    plt.ylabel('Values')
    plt.title(title)
    plt.legend()

    # Set x-axis ticks to be every 5 units
    plt.xticks(range(0, len(BQ_df), 10), fontsize=6)  # Adjust fontsize to make it smaller

# %%
plotting(BQ_df,'avg','ma',title = 'BQ. Queue length of presurgery room')

# %%
plotting(BQT_df,'avg','ma',title = 'Waiting time in presurgery room')

# %%
pd.to_pickle(data_df_dict,'data_df_dict.pickle')
pd.to_pickle(patient_df_dict,'patient_df_dict.pickle')
pd.to_pickle(stats_df_dict,'stats_df_dict.pickle')

# %%
a= pd.read_pickle('stats_df_dict.pickle')

# %%
# Out:
# {'5_0': fully_u               0.000000
#  eff_u                 9.526701
#  eff_b                 2.043607
#  eff_l                 4.400991
#  eff_s                18.593006
#  eff_g                 3.635861
#  eff_icu               7.715929
#  eff_ccu               1.984313
#  UQ_avg                0.000000
#  UQ_max                0.000000
#  BQ_avg                4.614475
#  BQ_max               27.000000
#  ELQ_avg               0.000533
#  ELQ_max               1.000000
#  NLQ_avg               0.000278
#  NLQ_max               1.000000
#  ESQ_avg               0.000000
#  ESQ_max               0.000000
#  NSQ_avg               0.000000
#  NSQ_max               0.000000
#  GQ_avg                7.710309
#  GQ_max               29.000000
#  ICQ_avg               0.000000
#  ICQ_max               0.000000
#  CCQ_avg               0.220115
#  CCQ_max               4.000000
#  avg_system_dur     5052.259222
#  sur_avg_complex       1.010309
#  more_than_24h         0.085736
#  dtype: float64,
#  '5_1': fully_u               0.000000
#  eff_u                 9.548542
#  eff_b                 4.382601
#  eff_l                 4.457033
#  eff_s                18.746648
#  eff_g                10.260498
#  eff_icu               7.879946
#  eff_ccu               2.377854
#  UQ_avg                0.000000
#  UQ_max                0.000000
#  BQ_avg                3.128279
#  BQ_max               27.000000
#  ELQ_avg               0.000184
#  ELQ_max               1.000000
#  NLQ_avg               0.000096
#  NLQ_max               1.000000
#  ESQ_avg               0.000000
#  ESQ_max               0.000000
#  NSQ_avg               0.000000
#  NSQ_max               0.000000
#  GQ_avg                3.380865
#  GQ_max               38.000000
#  ICQ_avg               0.000000
#  ICQ_max               0.000000
#  CCQ_avg               0.124682
#  CCQ_max               4.000000
#  avg_system_dur     4627.147164
#  sur_avg_complex       1.013158
#  more_than_24h         0.091141
#  dtype: float64,
#  '5_2': fully_u               0.000000
#  eff_u                 9.513782
#  eff_b                 3.423191
#  eff_l                 4.427908
#  eff_s                18.617491
#  eff_g                 6.844292
#  eff_icu               7.875490
#  eff_ccu               2.256576
#  UQ_avg                0.000000
#  UQ_max                0.000000
#  BQ_avg                5.181121
#  BQ_max               28.000000
#  ELQ_avg               0.000000
#  ELQ_max               0.000000
#  NLQ_avg               0.000136
#  NLQ_max               1.000000
#  ESQ_avg               0.000000
#  ESQ_max               0.000000
#  NSQ_avg               0.000000
#  NSQ_max               0.000000
#  GQ_avg                5.556517
#  GQ_max               35.000000
#  ICQ_avg               0.000000
#  ICQ_max               0.000000
#  CCQ_avg               0.133017
#  CCQ_max               3.000000
#  avg_system_dur     4909.787772
#  sur_avg_complex       1.011494
#  more_than_24h         0.195261
#  dtype: float64,
#  '5_3': fully_u               0.000000
#  eff_u                 9.528124
#  eff_b                 2.604469
#  eff_l                 4.416715
#  eff_s                18.672179
#  eff_g                 5.789680
#  eff_icu               7.944575
#  eff_ccu               2.360717
#  UQ_avg                0.000000
#  UQ_max                0.000000
#  BQ_avg                5.354853
#  BQ_max               24.000000
#  ELQ_avg               0.000000
#  ELQ_max               0.000000
#  NLQ_avg               0.000050
#  NLQ_max               1.000000
#  ESQ_avg               0.000000
#  ESQ_max               0.000000
#  NSQ_avg               0.000000
#  NSQ_max               0.000000
#  GQ_avg               12.100340
#  GQ_max               47.000000
#  ICQ_avg               0.000000
#  ICQ_max               0.000000
#  CCQ_avg               0.071488
#  CCQ_max               2.000000
#  avg_system_dur     5271.315013
#  sur_avg_complex       1.026667
#  more_than_24h         0.361285
#  dtype: float64,
#  '5_4': fully_u               0.000000
#  eff_u                 9.522792
#  eff_b                 4.236505
#  eff_l                 4.445752
#  eff_s                18.742506
#  eff_g                 7.210836
#  eff_icu               8.194155
#  eff_ccu               2.667816
#  UQ_avg                0.000000
#  UQ_max                0.000000
#  BQ_avg                2.952638
#  BQ_max               27.000000
#  ELQ_avg               0.000000
#  ELQ_max               0.000000
#  NLQ_avg               0.000000
#  NLQ_max               0.000000
#  ESQ_avg               0.000000
#  ESQ_max               0.000000
#  NSQ_avg               0.000000
#  NSQ_max               0.000000
#  GQ_avg                2.137201
#  GQ_max               19.000000
#  ICQ_avg               0.000000
#  ICQ_max               0.000000
#  CCQ_avg               0.045670
#  CCQ_max               3.000000
#  avg_system_dur     4664.341604
#  sur_avg_complex       1.000000
#  more_than_24h         0.034628
#  dtype: float64,
#  '5_5': fully_u               0.000000
#  eff_u                 9.536092
#  eff_b                 4.356562
#  eff_l                 4.449835
#  eff_s                18.701354
#  eff_g                10.017510
#  eff_icu               8.055765
#  eff_ccu               1.822894
#  UQ_avg                0.000000
#  UQ_max                0.000000
#  BQ_avg                2.203889
#  BQ_max               23.000000
#  ELQ_avg               0.000000
#  ELQ_max               0.000000
#  NLQ_avg               0.000000
#  NLQ_max               0.000000
#  ESQ_avg               0.000000
#  ESQ_max               0.000000
#  NSQ_avg               0.000000
#  NSQ_max               0.000000
#  GQ_avg                0.505341
#  GQ_max               16.000000
#  ICQ_avg               0.000000
#  ICQ_max               0.000000
#  CCQ_avg               0.451986
#  CCQ_max               5.000000
#  avg_system_dur     4471.027397
#  sur_avg_complex       1.025641
#  more_than_24h         0.006734
#  dtype: float64,
#  '5_6': fully_u               0.000000
#  eff_u                 9.546604
#  eff_b                 2.358972
#  eff_l                 4.416660
#  eff_s                18.613333
#  eff_g                 6.372211
#  eff_icu               7.613684
#  eff_ccu               2.108335
#  UQ_avg                0.000000
#  UQ_max                0.000000
#  BQ_avg                7.996705
#  BQ_max               29.000000
#  ELQ_avg               0.000133
#  ELQ_max               1.000000
#  NLQ_avg               0.000000
#  NLQ_max               0.000000
#  ESQ_avg               0.000000
#  ESQ_max               0.000000
#  NSQ_avg               0.000000
#  NSQ_max               0.000000
#  GQ_avg                5.895452
#  GQ_max               35.000000
#  ICQ_avg               0.000000
#  ICQ_max               0.000000
#  CCQ_avg               0.165258
#  CCQ_max               5.000000
#  avg_system_dur     5072.822464
#  sur_avg_complex       1.031915
#  more_than_24h         0.201091
#  dtype: float64,
#  '5_7': fully_u               0.000000
#  eff_u                 9.521372
#  eff_b                 3.702775
#  eff_l                 4.433580
#  eff_s                18.695770
#  eff_g                 6.723788
#  eff_icu               7.575641
#  eff_ccu               2.488934
#  UQ_avg                0.000000
#  UQ_max                0.000000
#  BQ_avg                2.151308
#  BQ_max               24.000000
#  ELQ_avg               0.000008
#  ELQ_max               1.000000
#  NLQ_avg               0.000073
#  NLQ_max               1.000000
#  ESQ_avg               0.000000
#  ESQ_max               0.000000
#  NSQ_avg               0.000000
#  NSQ_max               0.000000
#  GQ_avg                2.409076
#  GQ_max               21.000000
#  ICQ_avg               0.000000
#  ICQ_max               0.000000
#  CCQ_avg               0.093199
#  CCQ_max               4.000000
#  avg_system_dur     4625.935937
#  sur_avg_complex       1.040000
#  more_than_24h         0.011419
#  dtype: float64,
#  '5_8': fully_u               0.000000
#  eff_u                 9.522384
#  eff_b                 4.399588
#  eff_l                 4.446801
#  eff_s                18.676750
#  eff_g                 7.362942
#  eff_icu               7.590080
#  eff_ccu               2.067592
#  UQ_avg                0.000000
#  UQ_max                0.000000
#  BQ_avg                4.494662
#  BQ_max               37.000000
#  ELQ_avg               0.000017
#  ELQ_max               1.000000
#  NLQ_avg               0.000163
#  NLQ_max               2.000000
#  ESQ_avg               0.000000
#  ESQ_max               0.000000
#  NSQ_avg               0.000000
#  NSQ_max               0.000000
#  GQ_avg               15.754548
#  GQ_max               64.000000
#  ICQ_avg               0.000000
#  ICQ_max               0.000000
#  CCQ_avg               0.527406
#  CCQ_max               7.000000
#  avg_system_dur     5635.348191
#  sur_avg_complex       1.000000
#  more_than_24h         0.362553
#  dtype: float64,
#  '5_9': fully_u               0.000000
#  eff_u                 9.498960
#  eff_b                 2.203810
#  eff_l                 4.400698
#  eff_s                18.565386
#  eff_g                 4.934196
#  eff_icu               7.708538
#  eff_ccu               2.552688
#  UQ_avg                0.000000
#  UQ_max                0.000000
#  BQ_avg                5.708038
#  BQ_max               34.000000
#  ELQ_avg               0.000000
#  ELQ_max               0.000000
#  NLQ_avg               0.000000
#  NLQ_max               0.000000
#  ESQ_avg               0.000000
#  ESQ_max               0.000000
#  NSQ_avg               0.000000
#  NSQ_max               0.000000
#  GQ_avg               37.543041
#  GQ_max              105.000000
#  ICQ_avg               0.000000
#  ICQ_max               0.000000
#  CCQ_avg               0.066297
#  CCQ_max               3.000000
#  avg_system_dur     6528.641058
#  sur_avg_complex       1.010000
#  more_than_24h         0.532457
#  dtype: float64,
#  '5_10': fully_u               0.000000
#  eff_u                 9.544336
#  eff_b                 3.305376
#  eff_l                 4.433095
#  eff_s                18.703905
#  eff_g                 7.764896
#  eff_icu               8.172309
#  eff_ccu               2.046619
#  UQ_avg                0.000000
#  UQ_max                0.000000
#  BQ_avg                8.695640
#  BQ_max               44.000000
#  ELQ_avg               0.000000
#  ELQ_max               0.000000
#  NLQ_avg               0.000058
#  NLQ_max               1.000000
#  ESQ_avg               0.000000
#  ESQ_max               0.000000
#  NSQ_avg               0.000000
#  NSQ_max               0.000000
#  GQ_avg                3.491749
#  GQ_max               25.000000
#  ICQ_avg               0.000000
#  ICQ_max               0.000000
#  CCQ_avg               0.385520
#  CCQ_max               6.000000
#  avg_system_dur     5001.242704
#  sur_avg_complex       1.013699
#  more_than_24h         0.246973
#  dtype: float64,
#  '5_11': fully_u               0.000000
#  eff_u                 9.491309
#  eff_b                 3.510798
#  eff_l                 4.421230
#  eff_s                18.649585
#  eff_g                 6.750639
#  eff_icu               7.900164
#  eff_ccu               1.347433
#  UQ_avg                0.000000
#  UQ_max                0.000000
#  BQ_avg                2.412972
#  BQ_max               22.000000
#  ELQ_avg               0.000480
#  ELQ_max               2.000000
#  NLQ_avg               0.000000
#  NLQ_max               0.000000
#  ESQ_avg               0.000000
#  ESQ_max               0.000000
#  NSQ_avg               0.000000
#  NSQ_max               0.000000
#  GQ_avg               22.894581
#  GQ_max               64.000000
#  ICQ_avg               0.000000
#  ICQ_max               0.000000
#  CCQ_avg               0.642887
#  CCQ_max               5.000000
#  avg_system_dur     5735.753356
#  sur_avg_complex       1.000000
#  more_than_24h         0.489379
#  dtype: float64,
#  '5_12': fully_u               0.000000
#  eff_u                 9.500848
#  eff_b                 3.406004
#  eff_l                 4.422942
#  eff_s                18.660509
#  eff_g                 4.677683
#  eff_icu               7.608285
#  eff_ccu               2.044364
#  UQ_avg                0.000000
#  UQ_max                0.000000
#  BQ_avg                4.000192
#  BQ_max               26.000000
#  ELQ_avg               0.000520
#  ELQ_max               2.000000
#  NLQ_avg               0.000014
#  NLQ_max               1.000000
#  ESQ_avg               0.000000
#  ESQ_max               0.000000
#  NSQ_avg               0.000000
#  NSQ_max               0.000000
#  GQ_avg                6.378099
#  GQ_max               27.000000
#  ICQ_avg               0.000000
#  ICQ_max               0.000000
#  CCQ_avg               0.243797
#  CCQ_max               5.000000
#  avg_system_dur     4947.068707
#  sur_avg_complex       1.000000
#  more_than_24h         0.134850
#  dtype: float64,
#  '5_13': fully_u               0.000000
#  eff_u                 9.499933
#  eff_b                 3.380467
#  eff_l                 4.422184
#  eff_s                18.688464
#  eff_g                 3.311391
#  eff_icu               7.539355
#  eff_ccu               1.917612
#  UQ_avg                0.000000
#  UQ_max                0.000000
#  BQ_avg                2.068510
#  BQ_max               18.000000
#  ELQ_avg               0.000000
#  ELQ_max               0.000000
#  NLQ_avg               0.000063
#  NLQ_max               1.000000
#  ESQ_avg               0.000000
#  ESQ_max               0.000000
#  NSQ_avg               0.000000
#  NSQ_max               0.000000
#  GQ_avg                9.667955
#  GQ_max               38.000000
#  ICQ_avg               0.004862
#  ICQ_max               1.000000
#  CCQ_avg               0.191764
#  CCQ_max               4.000000
#  avg_system_dur     5150.028866
#  sur_avg_complex       1.015152
#  more_than_24h         0.065041
#  dtype: float64,
#  '5_14': fully_u               0.000000
#  eff_u                 9.521074
#  eff_b                 2.569207
#  eff_l                 4.412142
#  eff_s                18.632258
#  eff_g                 5.678334
#  eff_icu               7.993801
#  eff_ccu               2.206292
#  UQ_avg                0.000000
#  UQ_max                0.000000
#  BQ_avg                7.848642
#  BQ_max               32.000000
#  ELQ_avg               0.000039
#  ELQ_max               1.000000
#  NLQ_avg               0.000000
#  NLQ_max               0.000000
#  ESQ_avg               0.000000
#  ESQ_max               0.000000
#  NSQ_avg               0.000000
#  NSQ_max               0.000000
#  GQ_avg                7.212846
#  GQ_max               47.000000
#  ICQ_avg               0.000000
#  ICQ_max               0.000000
#  CCQ_avg               0.132776
#  CCQ_max               3.000000
#  avg_system_dur     5064.417477
#  sur_avg_complex       1.000000
#  more_than_24h         0.251362
#  dtype: float64,
#  '5_15': fully_u               0.000000
#  eff_u                 9.528310
#  eff_b                 1.959381
#  eff_l                 4.402928
#  eff_s                18.608130
#  eff_g                 4.432402
#  eff_icu               4.062339
#  eff_ccu               1.987828
#  UQ_avg                0.000000
#  UQ_max                0.000000
#  BQ_avg                6.841947
#  BQ_max               37.000000
#  ELQ_avg               0.000000
#  ELQ_max               0.000000
#  NLQ_avg               0.000000
#  NLQ_max               0.000000
#  ESQ_avg               0.000000
#  ESQ_max               0.000000
#  NSQ_avg               0.000000
#  NSQ_max               0.000000
#  GQ_avg               31.153575
#  GQ_max               74.000000
#  ICQ_avg               0.001839
#  ICQ_max               1.000000
#  CCQ_avg               0.315000
#  CCQ_max               5.000000
#  avg_system_dur     6400.645718
#  sur_avg_complex       1.011236
#  more_than_24h         0.632054
#  dtype: float64,
#  '5_16': fully_u               0.000000
#  eff_u                 9.483862
#  eff_b                 4.077537
#  eff_l                 4.430490
#  eff_s                18.686025
#  eff_g                 7.238386
#  eff_icu               7.922142
#  eff_ccu               1.302911
#  UQ_avg                0.000000
#  UQ_max                0.000000
#  BQ_avg                2.541088
#  BQ_max               20.000000
#  ELQ_avg               0.000000
#  ELQ_max               0.000000
#  NLQ_avg               0.000125
#  NLQ_max               1.000000
#  ESQ_avg               0.000000
#  ESQ_max               0.000000
#  NSQ_avg               0.000000
#  NSQ_max               0.000000
#  GQ_avg                2.119832
#  GQ_max               18.000000
#  ICQ_avg               0.000000
#  ICQ_max               0.000000
#  CCQ_avg               0.998766
#  CCQ_max              11.000000
#  avg_system_dur     4638.872574
#  sur_avg_complex       1.024390
#  more_than_24h         0.031720
#  dtype: float64,
#  '5_17': fully_u               0.000000
#  eff_u                 9.532109
#  eff_b                 2.595531
#  eff_l                 4.413266
#  eff_s                18.657124
#  eff_g                 5.810004
#  eff_icu               8.029681
#  eff_ccu               2.241542
#  UQ_avg                0.000000
#  UQ_max                0.000000
#  BQ_avg                3.480086
#  BQ_max               20.000000
#  ELQ_avg               0.000000
#  ELQ_max               0.000000
#  NLQ_avg               0.000287
#  NLQ_max               2.000000
#  ESQ_avg               0.000000
#  ESQ_max               0.000000
#  NSQ_avg               0.000000
#  NSQ_max               0.000000
#  GQ_avg                2.952660
#  GQ_max               25.000000
#  ICQ_avg               0.000000
#  ICQ_max               0.000000
#  CCQ_avg               0.182611
#  CCQ_max               4.000000
#  avg_system_dur     4641.966577
#  sur_avg_complex       1.000000
#  more_than_24h         0.024864
#  dtype: float64,
#  '5_18': fully_u               0.000000
#  eff_u                 9.477635
#  eff_b                 1.822950
#  eff_l                 4.383380
#  eff_s                18.578038
#  eff_g                 4.017613
#  eff_icu               7.415744
#  eff_ccu               2.102606
#  UQ_avg                0.000000
#  UQ_max                0.000000
#  BQ_avg               14.983257
#  BQ_max               41.000000
#  ELQ_avg               0.000058
#  ELQ_max               1.000000
#  NLQ_avg               0.000190
#  NLQ_max               1.000000
#  ESQ_avg               0.000000
#  ESQ_max               0.000000
#  NSQ_avg               0.000000
#  NSQ_max               0.000000
#  GQ_avg               49.622595
#  GQ_max              155.000000
#  ICQ_avg               0.000000
#  ICQ_max               0.000000
#  CCQ_avg               0.384539
#  CCQ_max               6.000000
#  avg_system_dur     7491.260483
#  sur_avg_complex       1.000000
#  more_than_24h         0.604214
#  dtype: float64,
#  '5_19': fully_u               0.000000
#  eff_u                 9.504840
#  eff_b                 2.619317
#  eff_l                 4.407331
#  eff_s                18.587926
#  eff_g                 3.473278
#  eff_icu               7.496077
#  eff_ccu               2.523836
#  UQ_avg                0.000000
#  UQ_max                0.000000
#  BQ_avg                5.899043
#  BQ_max               28.000000
#  ELQ_avg               0.000000
#  ELQ_max               0.000000
#  NLQ_avg               0.000000
#  NLQ_max               0.000000
#  ESQ_avg               0.000000
#  ESQ_max               0.000000
#  NSQ_avg               0.000000
#  NSQ_max               0.000000
#  GQ_avg               13.939780
#  GQ_max               43.000000
#  ICQ_avg               0.000000
#  ICQ_max               0.000000
#  CCQ_avg               0.087954
#  CCQ_max               4.000000
#  avg_system_dur     5443.017267
#  sur_avg_complex       1.021739
#  more_than_24h         0.306058
#  dtype: float64}

# %%
all_stats = pd.DataFrame(stats_df_dict)
all_stats.columns = [f'rep{i}' for i in range(1,16)]

# %%
all_stats
# Out:
#                         rep1         rep2         rep3         rep4  \
# fully_u             0.000000     0.000000     0.000000     0.000000
# eff_u               9.517017     9.527796     9.544872     9.555286
# eff_b               5.489589     5.159381     4.172386     2.165173
# eff_l               4.471431     4.467894     4.455155     4.415357
# eff_s              18.740953    18.746006    18.704775    18.611526
# eff_g               8.971033     6.798481     5.882541     3.892807
# eff_icu             3.759107     7.745317     7.097899     7.258345
# eff_ccu             1.899821     2.433561     2.338828     2.209037
# UQ_avg              0.000000     0.000000     0.000000     0.000000
# UQ_max              0.000000     0.000000     0.000000     0.000000
# BQ_avg              1.685476     1.180293     1.752633    11.282883
# BQ_max             21.000000    17.000000    14.000000    53.000000
# ELQ_avg             0.000000     0.000026     0.000093     0.000000
# ELQ_max             0.000000     1.000000     1.000000     0.000000
# NLQ_avg             0.000265     0.000045     0.000000     0.000000
# NLQ_max             1.000000     2.000000     0.000000     0.000000
# ESQ_avg             0.000000     0.000000     0.000000     0.000000
# ESQ_max             0.000000     0.000000     0.000000     0.000000
# NSQ_avg             0.000000     0.000000     0.000000     0.000000
# NSQ_max             0.000000     0.000000     0.000000     0.000000
# GQ_avg              0.403801     2.544324     2.018921    10.865299
# GQ_max             12.000000    33.000000    22.000000    42.000000
# ICQ_avg             0.001103     0.000000     0.000000     0.000000
# ICQ_max             1.000000     0.000000     0.000000     0.000000
# CCQ_avg             0.249072     0.029594     0.157480     0.247666
# CCQ_max             4.000000     2.000000     4.000000     5.000000
# avg_system_dur   4430.401191  4591.925064  4626.102419  5459.838946
# sur_avg_complex     1.000000     1.022222     1.010753     1.000000
# more_than_24h       0.001530     0.042049     0.005080     0.420122
#
#                         rep5         rep6         rep7         rep8  \
# fully_u             0.000000     0.000000     0.000000     0.000000
# eff_u               9.530737     9.553190     9.554055     9.508825
# eff_b               2.912410     3.272580     3.045988     3.571362
# eff_l               4.423077     4.439208     4.434567     4.429109
# eff_s              18.658945    18.663414    18.672009    18.669926
# eff_g               2.086242     5.390420     4.614465     4.578261
# eff_icu             8.089072     7.533172     7.514049     7.767972
# eff_ccu             1.574823     1.969037     2.047517     2.199163
# UQ_avg              0.000000     0.000000     0.000000     0.000000
# UQ_max              0.000000     0.000000     0.000000     0.000000
# BQ_avg              4.625131     5.186081     5.790942     2.383702
# BQ_max             37.000000    33.000000    29.000000    22.000000
# ELQ_avg             0.000000     0.000000     0.000000     0.000000
# ELQ_max             0.000000     0.000000     0.000000     0.000000
# NLQ_avg             0.000130     0.000000     0.000378     0.000000
# NLQ_max             1.000000     0.000000     3.000000     0.000000
# ESQ_avg             0.000000     0.000000     0.000000     0.000000
# ESQ_max             0.000000     0.000000     0.000000     0.000000
# NSQ_avg             0.000000     0.000000     0.000000     0.000000
# NSQ_max             0.000000     0.000000     0.000000     0.000000
# GQ_avg              7.184694     1.510218     5.687695     1.830314
# GQ_max             27.000000    20.000000    42.000000    19.000000
# ICQ_avg             0.000000     0.000000     0.000000     0.000000
# ICQ_max             0.000000     0.000000     0.000000     0.000000
# CCQ_avg             0.291316     0.353492     0.105286     0.308278
# CCQ_max             4.000000     4.000000     3.000000     4.000000
# avg_system_dur   5065.470762  4740.660605  4893.576851  4554.573146
# sur_avg_complex     1.021739     1.020000     1.000000     1.023256
# more_than_24h       0.108500     0.062718     0.122928     0.030367
#
#                         rep9        rep10        rep11        rep12  \
# fully_u             0.000000     0.000000     0.000000     0.000000
# eff_u               9.498193     9.533513     9.538263     9.513940
# eff_b               2.782779     3.206768     3.252080     2.225857
# eff_l               4.412581     4.431135     4.431958     4.404382
# eff_s              18.640984    18.677459    18.691896    18.579720
# eff_g               3.570501     4.594424     3.485221     1.615860
# eff_icu             3.840908     8.067168     7.950502     7.646901
# eff_ccu             1.601740     1.936356     2.012606     1.899898
# UQ_avg              0.000000     0.000000     0.000000     0.000000
# UQ_max              0.000000     0.000000     0.000000     0.000000
# BQ_avg              6.349198     4.127942     6.632231     5.075870
# BQ_max             38.000000    27.000000    38.000000    24.000000
# ELQ_avg             0.000124     0.000028     0.000145     0.000000
# ELQ_max             1.000000     1.000000     1.000000     0.000000
# NLQ_avg             0.000029     0.000211     0.000007     0.000193
# NLQ_max             1.000000     1.000000     1.000000     1.000000
# ESQ_avg             0.000000     0.000000     0.000000     0.000000
# ESQ_max             0.000000     0.000000     0.000000     0.000000
# NSQ_avg             0.000000     0.000000     0.000000     0.000000
# NSQ_max             0.000000     0.000000     0.000000     0.000000
# GQ_avg              9.003733     9.893947     2.557673     7.403676
# GQ_max             36.000000    63.000000    19.000000    31.000000
# ICQ_avg             0.001808     0.000000     0.000000     0.000000
# ICQ_max             1.000000     0.000000     0.000000     0.000000
# CCQ_avg             0.359554     0.404251     0.641063     0.505218
# CCQ_max             6.000000     6.000000     8.000000     4.000000
# avg_system_dur   5069.624805  5009.518044  4907.716087  5001.268768
# sur_avg_complex     1.000000     1.010753     1.025974     1.019802
# more_than_24h       0.282624     0.220506     0.119497     0.135909
#
#                        rep13        rep14        rep15
# fully_u             0.000000     0.000000     0.000000
# eff_u               9.511995     9.484280     9.536497
# eff_b               2.708006     3.675546     2.032901
# eff_l               4.412627     4.425037     4.402873
# eff_s              18.641138    18.655944    18.581905
# eff_g               0.782005     4.269424     1.435431
# eff_icu             7.857229     7.806721     7.609656
# eff_ccu             2.033488     2.340354     2.098279
# UQ_avg              0.000000     0.000000     0.000000
# UQ_max              0.000000     0.000000     0.000000
# BQ_avg              5.556531     3.250332     6.709788
# BQ_max             35.000000    26.000000    28.000000
# ELQ_avg             0.000260     0.000105     0.000000
# ELQ_max             2.000000     1.000000     0.000000
# NLQ_avg             0.000010     0.000194     0.000000
# NLQ_max             1.000000     1.000000     0.000000
# ESQ_avg             0.000000     0.000000     0.000000
# ESQ_max             0.000000     0.000000     0.000000
# NSQ_avg             0.000000     0.000000     0.000000
# NSQ_max             0.000000     0.000000     0.000000
# GQ_avg             17.961006     2.122299    19.343349
# GQ_max             49.000000    15.000000    48.000000
# ICQ_avg             0.000000     0.000000     0.000000
# ICQ_max             0.000000     0.000000     0.000000
# CCQ_avg             0.910290     0.118340     0.215134
# CCQ_max            11.000000     4.000000     6.000000
# avg_system_dur   5605.184866  4516.841029  5655.520089
# sur_avg_complex     1.010638     1.000000     1.000000
# more_than_24h       0.359756     0.001410     0.442579

# %%
bqt = pd.Series({f'rep{i}':BQT_df[i-1].mean for i in range(1,16)})
all_stats.loc['bqt'] = bqt
all_stats['std'] = all_stats.std(axis = 1)
all_stats['avg'] = all_stats.mean(axis = 1)

# %%
all_stats
# Out:
#                         rep1         rep2         rep3         rep4  \
# fully_u             0.000000     0.000000     0.000000     0.000000
# eff_u               9.517017     9.527796     9.544872     9.555286
# eff_b               5.489589     5.159381     4.172386     2.165173
# eff_l               4.471431     4.467894     4.455155     4.415357
# eff_s              18.740953    18.746006    18.704775    18.611526
# eff_g               8.971033     6.798481     5.882541     3.892807
# eff_icu             3.759107     7.745317     7.097899     7.258345
# eff_ccu             1.899821     2.433561     2.338828     2.209037
# UQ_avg              0.000000     0.000000     0.000000     0.000000
# UQ_max              0.000000     0.000000     0.000000     0.000000
# BQ_avg              1.685476     1.180293     1.752633    11.282883
# BQ_max             21.000000    17.000000    14.000000    53.000000
# ELQ_avg             0.000000     0.000026     0.000093     0.000000
# ELQ_max             0.000000     1.000000     1.000000     0.000000
# NLQ_avg             0.000265     0.000045     0.000000     0.000000
# NLQ_max             1.000000     2.000000     0.000000     0.000000
# ESQ_avg             0.000000     0.000000     0.000000     0.000000
# ESQ_max             0.000000     0.000000     0.000000     0.000000
# NSQ_avg             0.000000     0.000000     0.000000     0.000000
# NSQ_max             0.000000     0.000000     0.000000     0.000000
# GQ_avg              0.403801     2.544324     2.018921    10.865299
# GQ_max             12.000000    33.000000    22.000000    42.000000
# ICQ_avg             0.001103     0.000000     0.000000     0.000000
# ICQ_max             1.000000     0.000000     0.000000     0.000000
# CCQ_avg             0.249072     0.029594     0.157480     0.247666
# CCQ_max             4.000000     2.000000     4.000000     5.000000
# avg_system_dur   4430.401191  4591.925064  4626.102419  5459.838946
# sur_avg_complex     1.000000     1.022222     1.010753     1.000000
# more_than_24h       0.001530     0.042049     0.005080     0.420122
# bqt               556.198697   507.582619   639.390401  3716.559282
#
#                         rep5         rep6         rep7         rep8  \
# fully_u             0.000000     0.000000     0.000000     0.000000
# eff_u               9.530737     9.553190     9.554055     9.508825
# eff_b               2.912410     3.272580     3.045988     3.571362
# eff_l               4.423077     4.439208     4.434567     4.429109
# eff_s              18.658945    18.663414    18.672009    18.669926
# eff_g               2.086242     5.390420     4.614465     4.578261
# eff_icu             8.089072     7.533172     7.514049     7.767972
# eff_ccu             1.574823     1.969037     2.047517     2.199163
# UQ_avg              0.000000     0.000000     0.000000     0.000000
# UQ_max              0.000000     0.000000     0.000000     0.000000
# BQ_avg              4.625131     5.186081     5.790942     2.383702
# BQ_max             37.000000    33.000000    29.000000    22.000000
# ELQ_avg             0.000000     0.000000     0.000000     0.000000
# ELQ_max             0.000000     0.000000     0.000000     0.000000
# NLQ_avg             0.000130     0.000000     0.000378     0.000000
# NLQ_max             1.000000     0.000000     3.000000     0.000000
# ESQ_avg             0.000000     0.000000     0.000000     0.000000
# ESQ_max             0.000000     0.000000     0.000000     0.000000
# NSQ_avg             0.000000     0.000000     0.000000     0.000000
# NSQ_max             0.000000     0.000000     0.000000     0.000000
# GQ_avg              7.184694     1.510218     5.687695     1.830314
# GQ_max             27.000000    20.000000    42.000000    19.000000
# ICQ_avg             0.000000     0.000000     0.000000     0.000000
# ICQ_max             0.000000     0.000000     0.000000     0.000000
# CCQ_avg             0.291316     0.353492     0.105286     0.308278
# CCQ_max             4.000000     4.000000     3.000000     4.000000
# avg_system_dur   5065.470762  4740.660605  4893.576851  4554.573146
# sur_avg_complex     1.021739     1.020000     1.000000     1.023256
# more_than_24h       0.108500     0.062718     0.122928     0.030367
# bqt              1574.151336  1865.192826  2069.631162   859.535442
#
#                         rep9        rep10        rep11        rep12  \
# fully_u             0.000000     0.000000     0.000000     0.000000
# eff_u               9.498193     9.533513     9.538263     9.513940
# eff_b               2.782779     3.206768     3.252080     2.225857
# eff_l               4.412581     4.431135     4.431958     4.404382
# eff_s              18.640984    18.677459    18.691896    18.579720
# eff_g               3.570501     4.594424     3.485221     1.615860
# eff_icu             3.840908     8.067168     7.950502     7.646901
# eff_ccu             1.601740     1.936356     2.012606     1.899898
# UQ_avg              0.000000     0.000000     0.000000     0.000000
# UQ_max              0.000000     0.000000     0.000000     0.000000
# BQ_avg              6.349198     4.127942     6.632231     5.075870
# BQ_max             38.000000    27.000000    38.000000    24.000000
# ELQ_avg             0.000124     0.000028     0.000145     0.000000
# ELQ_max             1.000000     1.000000     1.000000     0.000000
# NLQ_avg             0.000029     0.000211     0.000007     0.000193
# NLQ_max             1.000000     1.000000     1.000000     1.000000
# ESQ_avg             0.000000     0.000000     0.000000     0.000000
# ESQ_max             0.000000     0.000000     0.000000     0.000000
# NSQ_avg             0.000000     0.000000     0.000000     0.000000
# NSQ_max             0.000000     0.000000     0.000000     0.000000
# GQ_avg              9.003733     9.893947     2.557673     7.403676
# GQ_max             36.000000    63.000000    19.000000    31.000000
# ICQ_avg             0.001808     0.000000     0.000000     0.000000
# ICQ_max             1.000000     0.000000     0.000000     0.000000
# CCQ_avg             0.359554     0.404251     0.641063     0.505218
# CCQ_max             6.000000     6.000000     8.000000     4.000000
# avg_system_dur   5069.624805  5009.518044  4907.716087  5001.268768
# sur_avg_complex     1.000000     1.010753     1.025974     1.019802
# more_than_24h       0.282624     0.220506     0.119497     0.135909
# bqt              2093.859383  1349.161245  2283.542955  1931.981598
#
#                        rep13        rep14        rep15         std  \
# fully_u             0.000000     0.000000     0.000000    0.000000
# eff_u               9.511995     9.484280     9.536497    0.021198
# eff_b               2.708006     3.675546     2.032901    1.004168
# eff_l               4.412627     4.425037     4.402873    0.021008
# eff_s              18.641138    18.655944    18.581905    0.048602
# eff_g               0.782005     4.269424     1.435431    2.165309
# eff_icu             7.857229     7.806721     7.609656    1.394532
# eff_ccu             2.033488     2.340354     2.098279    0.247281
# UQ_avg              0.000000     0.000000     0.000000    0.000000
# UQ_max              0.000000     0.000000     0.000000    0.000000
# BQ_avg              5.556531     3.250332     6.709788    2.591353
# BQ_max             35.000000    26.000000    28.000000    9.898533
# ELQ_avg             0.000260     0.000105     0.000000    0.000078
# ELQ_max             2.000000     1.000000     0.000000    0.639940
# NLQ_avg             0.000010     0.000194     0.000000    0.000122
# NLQ_max             1.000000     1.000000     0.000000    0.833809
# ESQ_avg             0.000000     0.000000     0.000000    0.000000
# ESQ_max             0.000000     0.000000     0.000000    0.000000
# NSQ_avg             0.000000     0.000000     0.000000    0.000000
# NSQ_max             0.000000     0.000000     0.000000    0.000000
# GQ_avg             17.961006     2.122299    19.343349    5.909205
# GQ_max             49.000000    15.000000    48.000000   14.686567
# ICQ_avg             0.000000     0.000000     0.000000    0.000529
# ICQ_max             0.000000     0.000000     0.000000    0.351866
# CCQ_avg             0.910290     0.118340     0.215134    0.225948
# CCQ_max            11.000000     4.000000     6.000000    2.203893
# avg_system_dur   5605.184866  4516.841029  5655.520089  388.741668
# sur_avg_complex     1.010638     1.000000     1.000000    0.010352
# more_than_24h       0.359756     0.001410     0.442579    0.152754
# bqt              2167.433033  1065.446836  2213.274992  859.412781
#
#                          avg
# fully_u             0.000000
# eff_u               8.933104
# eff_b               3.167311
# eff_l               4.154837
# eff_s              17.499075
# eff_g               4.008277
# eff_icu             6.808659
# eff_ccu             1.927612
# UQ_avg              0.000000
# UQ_max              0.000000
# BQ_avg              4.636274
# BQ_max             28.243658
# ELQ_avg             0.000054
# ELQ_max             0.539996
# NLQ_avg             0.000099
# NLQ_max             0.864613
# ESQ_avg             0.000000
# ESQ_max             0.000000
# NSQ_avg             0.000000
# NSQ_max             0.000000
# GQ_avg              6.640010
# GQ_max             30.792910
# ICQ_avg             0.000215
# ICQ_max             0.146992
# CCQ_avg             0.320124
# CCQ_max             4.825243
# avg_system_dur   4657.310271
# sur_avg_complex     0.948468
# more_than_24h       0.156771
# bqt              1609.522162

# %%
all_stats.to_excel('sytm1_stats.xlsx')
